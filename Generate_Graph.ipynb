# %%
# Downloads all of the necessary packages
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import scipy as sp
import plotly.express as px
from pathlib import Path
import os

# %%
# Path for master excel file
masterFile = "../../Wafer Particles/Wafer-Particles/Wafer_Particles.csv"

df = pd.read_csv(masterFile)
df
# Out:
#     Side     Grade Source/Destination  All  Lpd  Bin1  Bin2  Bin3  Bin4  Bin5  \
# 0      F  Rejected            1/5-1/5   67   35     4     2     3     3     1
# 1      F  Rejected          1/22-1/22  187  116     3     5     2    13     4
# 2      F  Rejected          1/10-1/10  299  124    10     7     8     7     4
# 3      F  Rejected          1/16-1/16  166   58     4     5     6     2     4
# 4      F  Rejected            1/2-1/2  712  657    10     4   208   152   122
# ..   ...       ...                ...  ...  ...   ...   ...   ...   ...   ...
# 99     F  Rejected          1/21-1/21   78   69    25    13    13     5     1
# 100    F  Rejected          1/22-1/22   23   16    10     1     3     1     0
# 101    F  Rejected          1/23-1/23   21   13     8     1     1     2     1
# 102    F  Rejected          1/13-1/13   37   31     9     3     1     4     1
# 103    F  Rejected          1/24-1/24  712  660    15     9   181   159   131
#
#      Bin6  Bin7  Bin8               Session     Lot_ID      Date  Time
# 0       3     0     3           ZZBARESI_HT  LONG TEST  20221013  1657
# 1      10     3    10           ZZBARESI_HT  LONG TEST  20221013  1657
# 2       6     6    13           ZZBARESI_HT  LONG TEST  20221013  1657
# 3       1     1     5           ZZBARESI_HT  LONG TEST  20221013  1657
# 4     101    42    18  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# ..    ...   ...   ...                   ...        ...       ...   ...
# 99      6     3     3  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 100     1     0     0  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 101     0     0     0  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 102     5     4     4  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 103    94    52    19  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
#
# [104 rows x 17 columns]
