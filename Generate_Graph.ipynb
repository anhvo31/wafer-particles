# %%
# Downloads all of the necessary packages
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import scipy as sp
import plotly.express as px
from pathlib import Path
import os

# %%
# Relative path for master excel file
masterFile = "../../Wafer Particles/Wafer-Particles/Wafer_Particles.csv"

df1 = pd.read_csv(masterFile)
df1
# Out:
#    Side     Grade Source/Destination  All  Lpd  Bin1  Bin2  Bin3  Bin4  Bin5  \
# 0     F  Rejected          1/25-1/25  833  775    50    38   216   162   129
# 1     F  Rejected            1/3-1/3  719  642    17     8   208   157   118
# 2     F  Rejected            1/4-1/4  841  755     6     8   208   184   146
# 3     F  Rejected            1/5-1/5  718  657    10     4   185   177   128
# 4     F  Rejected            1/6-1/6  702  614     8     4   190   150   115
# ..  ...       ...                ...  ...  ...   ...   ...   ...   ...   ...
# 95    F  Rejected          1/22-1/22   23   16    10     1     3     1     0
# 96    F  Rejected          1/23-1/23   21   13     8     1     1     2     1
# 97    F  Rejected          1/24-1/24   30   23     9     4     5     1     2
# 98    F  Rejected          1/14-1/14  228  175   105    24     9    10     6
# 99    F  Rejected            1/1-1/1   83   54    23    11     5     3     5
#
#     Bin6  Bin7  Bin8               Session     Lot_ID      Date  Time
# 0    110    59    11  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 1     80    43    11  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 2    131    59    13  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 3     92    47    14  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 4     78    58    11  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# ..   ...   ...   ...                   ...        ...       ...   ...
# 95     1     0     0  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 96     0     0     0  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 97     1     0     1  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 98     6     7     8  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 99     4     0     3  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
#
# [100 rows x 17 columns]

# %%
# Filtering the dataframe for a specific slot
df2 = df1.loc[df1['Source/Destination'].eq('1/5-1/5')]
df2
# Out:
#    Side     Grade Source/Destination  All  Lpd  Bin1  Bin2  Bin3  Bin4  Bin5  \
# 3     F  Rejected            1/5-1/5  718  657    10     4   185   177   128
# 28    F  Rejected            1/5-1/5   46   35    12     8     1     6     3
# 52    F  Rejected            1/5-1/5  711  651    13     4   185   178   130
# 78    F  Rejected            1/5-1/5   46   33    11     7     1     6     3
#
#     Bin6  Bin7  Bin8               Session     Lot_ID      Date  Time
# 3     92    47    14  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 28     2     2     1  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 52    74    54    13  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600
# 78     2     2     1  ZZBARESI_HT_MANUTEST  LONG TEST  20221205  1600

# %%
# Generates scatter plot based on axis values
df2.plot.scatter(x='Date', y='Lpd')
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Lpd'>
